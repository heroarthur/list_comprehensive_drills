# %%
from math import sqrt
X = Y = 15
[[' ' for col in range(0,Y)] for row in range(0,X)]
# Out:
# [[' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
# ...

# %%
[['@' if (col, row) in ((col, col), (col, col+1), (col, col-1))  else ' ' for col in range(0,Y)] for row in range(0,X)]
# Out:
# [['@', '@', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  ['@', '@', '@', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', '@', '@', '@', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', '@', '@', '@', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', '@', '@', '@', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', '@', '@', '@', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', '@', '@', '@', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', '@', '@', '@', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', '@', '@', '@', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '@', '@', '@', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '@', '@', '@', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '@', '@', '@', ' ', ' '],
# ...

# %%
[['@' if row+col in (X-2, X-1, X)  else ' ' for col in range(0,Y)] for row in range(0,X)]
# Out:
# [[' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '@', '@'],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '@', '@', '@'],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '@', '@', '@', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '@', '@', '@', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '@', '@', '@', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '@', '@', '@', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', '@', '@', '@', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', '@', '@', '@', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', '@', '@', '@', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', '@', '@', '@', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', '@', '@', '@', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', '@', '@', '@', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
# ...

# %%
[['@' if (col, row) in ((col, col), (col, col+1), (col, col-1)) or row+col in (X-2, X-1, X) else ' ' for col in range(0,Y)] for row in range(0,X)]
# Out:
# [['@', '@', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '@', '@'],
#  ['@', '@', '@', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '@', '@', '@'],
#  [' ', '@', '@', '@', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '@', '@', '@', ' '],
#  [' ', ' ', '@', '@', '@', ' ', ' ', ' ', ' ', ' ', '@', '@', '@', ' ', ' '],
#  [' ', ' ', ' ', '@', '@', '@', ' ', ' ', ' ', '@', '@', '@', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', '@', '@', '@', ' ', '@', '@', '@', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', '@', '@', '@', '@', '@', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', '@', '@', '@', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', '@', '@', '@', '@', '@', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', '@', '@', '@', ' ', '@', '@', '@', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', '@', '@', '@', ' ', ' ', ' ', '@', '@', '@', ' ', ' ', ' '],
#  [' ', ' ', '@', '@', '@', ' ', ' ', ' ', ' ', ' ', '@', '@', '@', ' ', ' '],
# ...

# %%
[['@' if row+col == X-1 or row == col or row == int(X/2) or col == int(X/2) else ' ' for col in range(0,Y)] for row in range(0,X)]
# Out:
# [['@', ' ', ' ', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', ' ', ' ', '@'],
#  [' ', '@', ' ', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', ' ', '@', ' '],
#  [' ', ' ', '@', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', '@', ' ', ' '],
#  [' ', ' ', ' ', '@', ' ', ' ', ' ', '@', ' ', ' ', ' ', '@', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', '@', ' ', ' ', '@', ' ', ' ', '@', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', '@', ' ', '@', ' ', '@', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', '@', '@', '@', ' ', ' ', ' ', ' ', ' ', ' '],
#  ['@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@'],
#  [' ', ' ', ' ', ' ', ' ', ' ', '@', '@', '@', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', '@', ' ', '@', ' ', '@', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', '@', ' ', ' ', '@', ' ', ' ', '@', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', '@', ' ', ' ', ' ', '@', ' ', ' ', ' ', '@', ' ', ' ', ' '],
# ...

# %%
r_x = X/2
r_y = X/2
r = 6
[['@' if sqrt((row-r_x)**2 + (col-r_y)**2) < r else ' ' for col in range(0,Y)] for row in range(0,X)]
# Out:
# [[' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', '@', '@', '@', '@', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', '@', '@', '@', '@', '@', '@', '@', '@', ' ', ' ', ' '],
#  [' ', ' ', ' ', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', ' ', ' '],
#  [' ', ' ', ' ', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', ' ', ' '],
#  [' ', ' ', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', ' '],
#  [' ', ' ', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', ' '],
#  [' ', ' ', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', ' '],
#  [' ', ' ', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', ' '],
#  [' ', ' ', ' ', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', ' ', ' '],
#  [' ', ' ', ' ', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', ' ', ' '],
# ...

# %%
[['@' if row+col in range(0,2*X,7) else ' ' for col in range(0,Y)] for row in range(0,X)]
# Out:
# [['@', ' ', ' ', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', ' ', ' ', '@'],
#  [' ', ' ', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', ' ', ' ', '@', ' '],
#  [' ', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', ' ', ' ', '@', ' ', ' '],
#  [' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' '],
#  [' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' '],
#  [' ', ' ', '@', ' ', ' ', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', ' '],
#  [' ', '@', ' ', ' ', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', ' ', ' '],
#  ['@', ' ', ' ', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', ' ', ' ', '@'],
#  [' ', ' ', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', ' ', ' ', '@', ' '],
#  [' ', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', ' ', ' ', '@', ' ', ' '],
#  [' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' '],
#  [' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' '],
# ...

# %%
[['@' if (col,row) in [(col, col+i*k) for i in range(0,X,7) for k in (1,-1)] else ' ' for col in range(0,Y)] for row in range(0,X)]
# Out:
# [['@', ' ', ' ', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', ' ', ' ', '@'],
#  [' ', '@', ' ', ' ', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', '@', ' ', ' ', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', ' ', ' ', '@', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', ' ', ' ', '@', ' '],
#  ['@', ' ', ' ', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', ' ', ' ', '@'],
#  [' ', '@', ' ', ' ', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', '@', ' ', ' ', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' '],
# ...

# %%
density = 7
[['@' if row+col in range(0,2*X,density) or (col,row) in [(col, col+i*k) for i in range(0,X,density) for k in (1,-1)] else ' ' for col in range(0,Y)] for row in range(0,X)]
# Out:
# [['@', ' ', ' ', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', ' ', ' ', '@'],
#  [' ', '@', ' ', ' ', ' ', ' ', '@', ' ', '@', ' ', ' ', ' ', ' ', '@', ' '],
#  [' ', ' ', '@', ' ', ' ', '@', ' ', ' ', ' ', '@', ' ', ' ', '@', ' ', ' '],
#  [' ', ' ', ' ', '@', '@', ' ', ' ', ' ', ' ', ' ', '@', '@', ' ', ' ', ' '],
#  [' ', ' ', ' ', '@', '@', ' ', ' ', ' ', ' ', ' ', '@', '@', ' ', ' ', ' '],
#  [' ', ' ', '@', ' ', ' ', '@', ' ', ' ', ' ', '@', ' ', ' ', '@', ' ', ' '],
#  [' ', '@', ' ', ' ', ' ', ' ', '@', ' ', '@', ' ', ' ', ' ', ' ', '@', ' '],
#  ['@', ' ', ' ', ' ', ' ', ' ', ' ', '@', ' ', ' ', ' ', ' ', ' ', ' ', '@'],
#  [' ', '@', ' ', ' ', ' ', ' ', '@', ' ', '@', ' ', ' ', ' ', ' ', '@', ' '],
#  [' ', ' ', '@', ' ', ' ', '@', ' ', ' ', ' ', '@', ' ', ' ', '@', ' ', ' '],
#  [' ', ' ', ' ', '@', '@', ' ', ' ', ' ', ' ', ' ', '@', '@', ' ', ' ', ' '],
#  [' ', ' ', ' ', '@', '@', ' ', ' ', ' ', ' ', ' ', '@', '@', ' ', ' ', ' '],
# ...

# %%
[['@' if row < col/2 or row >= col**1.4 else ' ' for col in range(0,Y)] for row in range(0,X)]
# Out:
# [['@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@'],
#  ['@', '@', ' ', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@'],
#  ['@', '@', ' ', ' ', ' ', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@'],
#  ['@', '@', '@', ' ', ' ', ' ', ' ', '@', '@', '@', '@', '@', '@', '@', '@'],
#  ['@', '@', '@', ' ', ' ', ' ', ' ', ' ', ' ', '@', '@', '@', '@', '@', '@'],
#  ['@', '@', '@', '@', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '@', '@', '@', '@'],
#  ['@', '@', '@', '@', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '@', '@'],
#  ['@', '@', '@', '@', '@', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  ['@', '@', '@', '@', '@', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  ['@', '@', '@', '@', '@', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  ['@', '@', '@', '@', '@', '@', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  ['@', '@', '@', '@', '@', '@', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
# ...

# %%
3//2
# Out:
# 1
